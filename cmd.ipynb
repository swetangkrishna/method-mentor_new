# %%
# !git clone https://github.com/swetangkrishna/method-mentor_new.git
# Out:
# Cloning into 'method-mentor_new'...
# remote: Enumerating objects: 134, done.
# remote: Counting objects: 100% (134/134), done.
# remote: Compressing objects: 100% (75/75), done.
# remote: Total 134 (delta 67), reused 123 (delta 56), pack-reused 0 (from 0)
# Receiving objects: 100% (134/134), 671.31 KiB | 912.00 KiB/s, done.
# Resolving deltas: 100% (67/67), done.
# Updating files: 100% (113/113), done.
